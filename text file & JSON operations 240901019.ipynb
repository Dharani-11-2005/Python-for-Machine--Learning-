# %%
#open a text file in 'Write' mode to write the given lines
f=open("D:\textfile.txt",'w')
f.write("first line\n")
f.write("second line\n")
f.write("third line\n")
f.close()
#Open a text file in'Read' mode to read and print the available lines-readline funcion
k=open("D:\textfile.txt",'r')
print(k.readline())
print(k.readline())
print(k.readline())
k.close()
# Out:
# first line
#
# second line
#
# third line

# %%
#Open a text file in 'Append' mode to add/append new line inputs
m=open("D:\textfile.txt",'a')
m.write("fourth line\n")
m.write("fifth line\n")
m.close()
#Open a text file in 'Read' mode to read and print the available full text-read function
p=open("D:\textfile.txt",'r')
print(p.read())
p.close()
# Out:
# first line
# second line
# third line
# fourth line
# fifth line
# fourth line
# fifth line

# %%
with open("D:\textfile.txt",'r') as file:
     lines=file.readlines()
     print(lines)
# Out:
# ['first line\n', 'second line\n', 'third line\n', 'fourth line\n', 'fifth line\n', 'fourth line\n', 'fifth line\n']

# %%
import json
x='{"name":"John","age":30,"city":"New York"}'
y=json.loads(x)
print(y["age"])
# Out:
# 30

# %%
data={
    "name":"John",
    "age":30,
    "city":"New York"
}
json_data=json.dumps(data)
print(json_data)
# Out:
# {"name": "John", "age": 30, "city": "New York"}
